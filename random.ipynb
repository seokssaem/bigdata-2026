# %%
import random

date1 = ['2026-05-18', '2026-05-19', '2026-05-20', '2026-05-21', '2026-05-22', '2026-05-26', '2026-05-27', '2026-05-28', '2026-05-29']
len(date1)
date1_name = ['김나현', '김동욱', '홍은경', '태두혁', '장호균', '김수완']  # 김수완은 아직 응답 안함

# %%
date2 = ['2026-05-26', '2026-05-27', '2026-05-28', '2026-05-29']
date2_name = '김기완'  # '2026-05-28'

# %%
date3 = ['2026-05-18', '2026-05-19', '2026-05-20', '2026-05-21','2026-05-26', '2026-05-27']
date3_name = '노가희' # '2026-05-26'

# %%
date4 = ['2026-05-18', '2026-05-19', '2026-05-20', '2026-05-27', '2026-05-28', '2026-05-29']
date4_name = '김시현'  # '2026-05-27'

# %%
import random

random.choice(date2)  # 김기완
# Out:
# '2026-05-29'

# %%
import random

random.choice(date3) # 노가희
# Out:
# '2026-05-18'

# %%
import random

random.choice(date4)
# Out:
# '2026-05-27'

# %%
date1_re = [ '2026-05-18', '2026-05-19', '2026-05-20', '2026-05-21', '2026-05-22', '2026-05-29']
date1_name
# Out:
# ['김나현', '김동욱', '홍은경', '태두혁', '장호균', '김수완']

# %%
random.shuffle(date1_name)

result = dict(zip(date1_re, date1_name))

# %%
result
# Out:
# {'2026-05-18': '태두혁',
#  '2026-05-19': '홍은경',
#  '2026-05-20': '김수완',
#  '2026-05-21': '장호균',
#  '2026-05-22': '김나현',
#  '2026-05-29': '김동욱'}

# %%
result2 = {'2026-05-26':'노가희', '2026-05-27':'김시현', '2026-05-28':'김기완'}

# %%
result_final = dict(sorted((result | result2).items()))

# %%
result_final
# Out:
# {'2026-05-18': '태두혁',
#  '2026-05-19': '홍은경',
#  '2026-05-20': '김수완',
#  '2026-05-21': '장호균',
#  '2026-05-22': '김나현',
#  '2026-05-26': '노가희',
#  '2026-05-27': '김시현',
#  '2026-05-28': '김기완',
#  '2026-05-29': '김동욱'}

# %%
result_df = {'날짜':result_final.keys(), '이름':result_final.values()}

# %%
import pandas as pd

df = pd.DataFrame(result_df)
df
# Out:
#            날짜   이름
# 0  2026-05-18  태두혁
# 1  2026-05-19  홍은경
# 2  2026-05-20  김수완
# 3  2026-05-21  장호균
# 4  2026-05-22  김나현
# 5  2026-05-26  노가희
# 6  2026-05-27  김시현
# 7  2026-05-28  김기완
# 8  2026-05-29  김동욱
